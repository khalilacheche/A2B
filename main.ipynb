# %%
import requests


def fetch_stations(latitude, longitude, radius=10000, limit=50):
    API_URL = "https://journey-service-int.api.sbb.ch/v3/places/by-coordinates"
    CLIENT_SECRET = "MU48Q~IuD6Iawz3QfvkmMiKHtfXBf-ffKoKTJdt5"
    CLIENT_ID = "f132a280-1571-4137-86d7-201641098ce8"
    SCOPE = "c11fa6b1-edab-4554-a43d-8ab71b016325/.default"

    def get_token():
        params = {
            "grant_type": "client_credentials",
            "scope": SCOPE,
            "client_id": CLIENT_ID,
            "client_secret": CLIENT_SECRET,
        }
        return requests.post(
            "https://login.microsoftonline.com/2cda5d11-f0ac-46b3-967d-af1b2e1bd01a/oauth2/v2.0/token",
            data=params,
        ).json()

    headers = {
        "accept": "application/json",
        "Accept-Language": "en",
        "Authorization": f"Bearer {get_token()['access_token']}",
    }

    params = {
        "longitude": longitude,
        "latitude": latitude,
        "radius": radius,
        "limit": limit,
        "type": "StopPlace",
        "includeVehicleModes": "false",
    }

    response = requests.get(API_URL, params=params, headers=headers, timeout=5)
    try:
        places = response.json()["places"]
        res = []
        for place in places:
            res.append(
                {
                    "name": place["name"],
                    "id": place["id"],
                    "coordinates": place["centroid"]["coordinates"],
                    "distance": place["distanceToSearchPosition"],
                }
            )
        res.sort(key=lambda x: x["distance"])
        return res
    except:
        return None

# %%
lat = "46.523904"
lon = "6.564732"


res = fetch_stations(lat,lon)

# %%
res
# Out:
# [{'name': 'Ecublens VD, Bassenges',
#   'id': '8501215',
#   'coordinates': [6.564588, 46.524588],
#   'distance': 76},
#  {'name': 'Ecublens VD, EPFL',
#   'id': '8501214',
#   'coordinates': [6.566144, 46.522197],
#   'distance': 218},
#  {'name': 'Ecublens VD, EPFL (bus)',
#   'id': '8579233',
#   'coordinates': [6.566872, 46.522054],
#   'distance': 263},
#  {'name': 'Ecublens VD, Coquerellaz',
#   'id': '8591947',
#   'coordinates': [6.560516, 46.523744],
#   'distance': 323},
#  {'name': 'Ecublens VD, Motty',
#   'id': '8591951',
#   'coordinates': [6.561568, 46.525874],
#   'distance': 326},
#  {'name': 'Ecublens VD, Cerisaie',
#   'id': '8501216',
#   'coordinates': [6.566548, 46.527753],
#   'distance': 449},
#  {'name': 'Ecublens VD, Ormet',
#   'id': '8591952',
#   'coordinates': [6.558871, 46.523609],
#   'distance': 449},
#  {'name': 'Ecublens VD, EPFL Piccard',
#   'id': '8579234',
#   'coordinates': [6.568454, 46.520373],
#   'distance': 485},
#  {'name': 'Ecublens VD, Perrettes',
#   'id': '8591954',
#   'coordinates': [6.558449, 46.526207],
#   'distance': 544},
#  {'name': 'Ecublens VD, Cocarde',
#   'id': '8591946',
#   'coordinates': [6.560435, 46.527959],
#   'distance': 558},
#  {'name': 'Ecublens VD, En Enjalin',
#   'id': '8591949',
#   'coordinates': [6.557074, 46.524211],
#   'distance': 587},
#  {'name': 'Ecublens VD, EPFL/Colladon',
#   'id': '8510727',
#   'coordinates': [6.563591, 46.51808],
#   'distance': 653},
#  {'name': 'Ecublens VD, Pontet',
#   'id': '8588873',
#   'coordinates': [6.566018, 46.529784],
#   'distance': 661},
#  {'name': 'Ecublens VD, Argand',
#   'id': '8591944',
#   'coordinates': [6.57187, 46.520337],
#   'distance': 675},
#  {'name': 'Ecublens VD, Villars',
#   'id': '8591961',
#   'coordinates': [6.561119, 46.529524],
#   'distance': 683},
#  {'name': 'Ecublens VD, UNIL-Sorge',
#   'id': '8501213',
#   'coordinates': [6.573578, 46.522449],
#   'distance': 696},
#  {'name': 'Ecublens VD, Renges',
#   'id': '8591956',
#   'coordinates': [6.554745, 46.52253],
#   'distance': 779},
#  {'name': 'Chavannes-R., Plaine',
#   'id': '8593867',
#   'coordinates': [6.572346, 46.528562],
#   'distance': 779},
#  {'name': 'Ecublens VD, Veilloud',
#   'id': '8591960',
#   'coordinates': [6.564499, 46.531258],
#   'distance': 818},
#  {'name': 'St-Sulpice VD, Parc Scient.',
#   'id': '8595223',
#   'coordinates': [6.563779, 46.516579],
#   'distance': 818},
#  {'name': 'Chavannes-R., Berges',
#   'id': '8594986',
#   'coordinates': [6.574971, 46.527492],
#   'distance': 879},
#  {'name': 'St-Sulpice VD, Pâqueret',
#   'id': '8592227',
#   'coordinates': [6.570449, 46.516651],
#   'distance': 918},
#  {'name': 'Ecublens VD, Champagne',
#   'id': '8591945',
#   'coordinates': [6.573874, 46.518548],
#   'distance': 919},
#  {'name': 'Chavannes-R., Cèdres',
#   'id': '8507227',
#   'coordinates': [6.572904, 46.530153],
#   'distance': 934},
#  {'name': 'St-Sulpice VD, Russel',
#   'id': '8592226',
#   'coordinates': [6.563914, 46.515132],
#   'distance': 978},
#  {'name': 'Ecublens VD, Stand',
#   'id': '8591957',
#   'coordinates': [6.562476, 46.53276],
#   'distance': 1000},
#  {'name': 'St-Sulpice VD, Pré-Fleuri',
#   'id': '8510528',
#   'coordinates': [6.560507, 46.515141],
#   'distance': 1027},
#  {'name': 'Chavannes-R., Crochy',
#   'id': '8501217',
#   'coordinates': [6.569973, 46.532715],
#   'distance': 1058},
#  {'name': 'Ecublens VD, Montaney',
#   'id': '8594890',
#   'coordinates': [6.552786, 46.518817],
#   'distance': 1075},
#  {'name': 'Ecublens VD, Blévallaire',
#   'id': '8596053',
#   'coordinates': [6.577263, 46.519501],
#   'distance': 1077},
#  {'name': 'Chavannes-R., UNIL-Mouline',
#   'id': '8501212',
#   'coordinates': [6.578899, 46.524993],
#   'distance': 1091},
#  {'name': 'Ecublens VD, Larges Pièces',
#   'id': '8592248',
#   'coordinates': [6.555923, 46.531744],
#   'distance': 1102},
#  {'name': 'Chavannes-R., Mouline',
#   'id': '8594987',
#   'coordinates': [6.579349, 46.526171],
#   'distance': 1146},
#  {'name': 'Chavannes-R., Concorde',
#   'id': '8593868',
#   'coordinates': [6.574324, 46.532346],
#   'distance': 1191},
#  {'name': 'Ecublens VD, Croset',
#   'id': '8591948',
#   'coordinates': [6.566368, 46.534692],
#   'distance': 1206},
#  {'name': 'St-Sulpice VD, Bochet',
#   'id': '8588157',
#   'coordinates': [6.559465, 46.513334],
#   'distance': 1243},
#  {'name': 'Ecublens VD, place de sport',
#   'id': '8591955',
#   'coordinates': [6.563833, 46.535259],
#   'distance': 1264},
#  {'name': 'St-Sulpice VD, Ochettaz-Ormet',
#   'id': '8510527',
#   'coordinates': [6.556435, 46.513792],
#   'distance': 1291},
#  {'name': 'Chavannes-R., Planta',
#   'id': '8591933',
#   'coordinates': [6.573029, 46.534198],
#   'distance': 1309},
#  {'name': 'Ecublens VD, allée de Dorigny',
#   'id': '8591950',
#   'coordinates': [6.582234, 46.52048],
#   'distance': 1392},
#  {'name': 'Ecublens VD, Champs-Courbes',
#   'id': '8591959',
#   'coordinates': [6.550089, 46.516345],
#   'distance': 1401},
#  {'name': 'Ecublens VD, Parc',
#   'id': '8591953',
#   'coordinates': [6.568067, 46.536976],
#   'distance': 1476},
#  {'name': 'Chavannes-R., Dorigny',
#   'id': '8595602',
#   'coordinates': [6.583915, 46.526755],
#   'distance': 1502},
#  {'name': 'Chavannes-R., Talluchet',
#   'id': '8510422',
#   'coordinates': [6.583448, 46.528652],
#   'distance': 1526},
#  {'name': 'Chavannes-R., UNIL-Chamberonne',
#   'id': '8501211',
#   'coordinates': [6.584706, 46.52422],
#   'distance': 1529},
#  {'name': 'Chavannes-R., Préfaully',
#   'id': '8593866',
#   'coordinates': [6.579097, 46.533587],
#   'distance': 1539},
#  {'name': 'St-Sulpice VD, En Champagny',
#   'id': '8510526',
#   'coordinates': [6.550215, 46.513837],
#   'distance': 1577},
#  {'name': 'St-Sulpice VD, centre',
#   'id': '8588158',
#   'coordinates': [6.558098, 46.51008],
#   'distance': 1619},
#  {'name': 'Lausanne, sports UNIL-EPFL',
#   'id': '8595937',
#   'coordinates': [6.585839, 46.521056],
#   'distance': 1646},
#  {'name': 'Chavannes-R., Glycines',
#   'id': '8593869',
#   'coordinates': [6.57658, 46.536283],
#   'distance': 1648}]
